# %%
import pdb
import time
import numpy as np
import librosa

import tensorflow as tf

from networks import *

# %%
def flatten_sequence(sequence, factor):
    
    seq_length = sequence.shape[-1]
    length = seq_length//factor
    seq_length_diff = seq_length - length

    sequence_flat = np.zeros(tf.size(sequence).numpy()*factor)
    for n in range(len(sequence)):
        point = n*length
        if n==0:
            sequence_flat[:seq_length] = sequence[n]
        else:
            sequence_flat[point:point+seq_length_diff] = sequence_flat[point:point+seq_length_diff] + sequence[n][:-length]
            sequence_flat[point+seq_length_diff:point+seq_length_diff+length] = sequence[n][-length:]

    sequence_flat = sequence_flat[:point+seq_length]
    
    for n in range(factor-1):
        point = n*length
        sequence_flat[point:point+length] = sequence_flat[point:point+length]/(n+1)
        if n==0:
            sequence_flat[-point-length:] = sequence_flat[-point-length:]/(n+1)
        else:
            sequence_flat[-point-length:-point] = sequence_flat[-point-length:-point]/(n+1)
        
    sequence_flat[(factor-1)*length:-(factor-1)*length] = sequence_flat[(factor-1)*length:-(factor-1)*length]/factor
    
    return sequence_flat

# %%
# Onset Detection

num_iter = 10
num_stages = 6

sequence_length = 16
factor_div = 4

#Models_OD = ['CNN','BRNN','RNN','RNN_Stateful','CRNN_1_Timing']
Models_OD = ['CNN','BRNN','RNN']
Times_OD = np.zeros((num_iter,num_stages,len(Models_OD)))

# Preprocess Parameters

hop_size = 128
frame_size = 256

for a in range(len(Models_OD)):

    for N in range(num_iter):

        Model_OD = Models_OD[a]

        print('\n')
        print([N,a])
        print('\n')

        # Onset Detection Parameters

        if Model_OD=='BRNN':
            sequence_length = 16
            model = BRNN_1(sequence_length,0)
            hop = 4
        elif Model_OD=='CNN':
            sequence_length = 16
            model = CNN_T_1(sequence_length,0)
            hop = 4
        elif Model_OD=='RNN':
            sequence_length = 8
            model = RNN_1(sequence_length,0)
            hop = 1
        elif Model_OD=='RNN_Stateful':
            sequence_length = 16
            model = RNN_Stateful_1(sequence_length,0)
            hop = 1
        elif Model_OD=='CRNN_Timing':
            sequence_length = 10
            model = CRNN_1_Timing(13,[16,32,64],sequence_length,0)
            hop = 1

        # Onset Detection

        audio = np.random.rand(120*22050)

        start = time.time()

        Tensor_All_0 = np.abs(librosa.stft(audio, n_fft=frame_size, hop_length=hop_size, win_length=frame_size, window='hann')).T
        print(Tensor_All_0.shape)
        Tensor_All_0 = np.flipud(Tensor_All_0[:,1:])
        print(Tensor_All_0.shape)

        Time_1 = time.time()-start
        print('Spectrogram Time: {:.4f}'.format(Time_1))
        print('Spectrogram Time per second: {:.4f}'.format(Time_1/(len(audio)/22050)))
        print('\n')
        Times_OD[N,0,a] = Time_1/(len(audio)/22050)
        start = time.time()

        length = Tensor_All_0.shape[0]-sequence_length+1
        Tensor_All = np.zeros(shape=(length,sequence_length,Tensor_All_0.shape[1]))
        for n in range(sequence_length):
            Tensor_All[:,n] = Tensor_All_0[n:length+n]
        if Model_OD!='RNN':
            Tensor_All = Tensor_All[::factor_div]

        Time_2 = time.time()-start
        print('Preprocess Time: {:.4f}'.format(Time_2))
        print('Preprocess Time per second: {:.4f}'.format(Time_2/(len(audio)/22050)))
        print('\n')
        Times_OD[N,1,a] = Time_2/(len(audio)/22050)
        start = time.time()

        Tensor_All = np.log(Tensor_All+1e-4)
        Tensor_All = (Tensor_All-0)/(1-0+1e-16)
        if Model_OD=='CNN' or Model_OD=='CRNN_Timing':
            Tensor_All = np.expand_dims(Tensor_All,axis=-1)

        Time_3 = time.time()-start
        print('Prediction Time: {:.4f}'.format(Time_3))
        print('Prediction Time per second: {:.4f}'.format(Time_3/(len(audio)/22050)))
        print('\n')
        Times_OD[N,2,a] = Time_3/(len(audio)/22050)
        start = time.time()

        predictions = model.predict(Tensor_All)

        Time_4 = time.time()-start
        print('Prediction Time: {:.4f}'.format(Time_4))
        print('Prediction Time per second: {:.4f}'.format(Time_4/(len(audio)/22050)))
        print('\n')
        Times_OD[N,3,a] = Time_4/(len(audio)/22050)
        start = time.time()

        #predictions = model(Tensor_All)
        if Model_OD!='RNN' and Model_OD!='CRNN_Timing':
            Prediction = flatten_sequence(tf.math.sigmoid(predictions), factor_div)

        Time_5 = time.time()-start
        print('Prediction Time: {:.4f}'.format(Time_5))
        print('Prediction Time per second: {:.4f}'.format(Time_5/(len(audio)/22050)))
        print('\n')
        Times_OD[N,4,a] = Time_5/(len(audio)/22050)
        start = time.time()

        Time_OD = Time_1 + Time_2 + Time_3 + Time_4
        print('Total Time: {:.4f}'.format(Time_OD))
        print('Total Time per second: {:.4f}'.format(Time_OD/(len(audio)/22050)))
        print('\n')
        Times_OD[N,5,a] = Time_OD/(len(audio)/22050)
# Out:
# [0, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0929
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2065
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2634
# Prediction Time per second: 0.0022
#
#
# Prediction Time: 11.5263
# Prediction Time per second: 0.0961
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 12.0891
# Total Time per second: 0.1007
#
#
#
#
# [1, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0964
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2082
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2203
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 2.0333
# Prediction Time per second: 0.0169
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.5583
# Total Time per second: 0.0213
#
#
#
#
# [2, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0935
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2113
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2299
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 2.0464
# Prediction Time per second: 0.0171
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.5811
# Total Time per second: 0.0215
#
#
#
#
# [3, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0914
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2107
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2504
# Prediction Time per second: 0.0021
#
#
# Prediction Time: 2.1432
# Prediction Time per second: 0.0179
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.6957
# Total Time per second: 0.0225
#
#
#
#
# [4, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0968
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2076
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2256
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 2.1373
# Prediction Time per second: 0.0178
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.6674
# Total Time per second: 0.0222
#
#
#
#
# [5, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0966
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2148
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2279
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 2.1969
# Prediction Time per second: 0.0183
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.7362
# Total Time per second: 0.0228
#
#
#
#
# [6, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1021
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.2133
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2265
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 2.1976
# Prediction Time per second: 0.0183
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.7395
# Total Time per second: 0.0228
#
#
#
#
# [7, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0935
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2087
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2267
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 2.2405
# Prediction Time per second: 0.0187
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.7694
# Total Time per second: 0.0231
#
#
#
#
# [8, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1036
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.2202
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2376
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 2.3459
# Prediction Time per second: 0.0195
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.9073
# Total Time per second: 0.0242
#
#
#
#
# [9, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0754
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2161
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2346
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 2.3196
# Prediction Time per second: 0.0193
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.8456
# Total Time per second: 0.0237
#
#
#
#
# [0, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0849
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.2111
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2376
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 2.5103
# Prediction Time per second: 0.0209
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 3.0439
# Total Time per second: 0.0254
#
#
#
#
# [1, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1018
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2060
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2352
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 2.4782
# Prediction Time per second: 0.0207
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 3.0213
# Total Time per second: 0.0252
#
#
#
#
# [2, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0739
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2024
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2327
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 2.4915
# Prediction Time per second: 0.0208
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 3.0005
# Total Time per second: 0.0250
#
#
#
#
# [3, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0991
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2072
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2429
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 2.4209
# Prediction Time per second: 0.0202
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.9701
# Total Time per second: 0.0248
#
#
#
#
# [4, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1046
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.2101
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2362
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 2.9484
# Prediction Time per second: 0.0246
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 3.4993
# Total Time per second: 0.0292
#
#
#
#
# [5, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1000
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2039
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2409
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 2.4903
# Prediction Time per second: 0.0208
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 3.0351
# Total Time per second: 0.0253
#
#
#
#
# [6, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1064
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.2203
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2389
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 2.8413
# Prediction Time per second: 0.0237
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 3.4068
# Total Time per second: 0.0284
#
#
#
#
# [7, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0976
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2111
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2469
# Prediction Time per second: 0.0021
#
#
# Prediction Time: 2.4740
# Prediction Time per second: 0.0206
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 3.0296
# Total Time per second: 0.0252
#
#
#
#
# [8, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0930
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2013
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2262
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 2.3601
# Prediction Time per second: 0.0197
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.8806
# Total Time per second: 0.0240
#
#
#
#
# [9, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0984
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.2059
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2303
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 2.8192
# Prediction Time per second: 0.0235
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 3.3539
# Total Time per second: 0.0279
#
#
#
#
# [0, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1023
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.1098
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5030
# Prediction Time per second: 0.0042
#
#
# Prediction Time: 1.1926
# Prediction Time per second: 0.0099
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.9076
# Total Time per second: 0.0159
#
#
#
#
# [1, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0959
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.1072
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5028
# Prediction Time per second: 0.0042
#
#
# Prediction Time: 1.1269
# Prediction Time per second: 0.0094
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.8328
# Total Time per second: 0.0153
#
#
#
#
# [2, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0955
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.1139
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.4994
# Prediction Time per second: 0.0042
#
#
# Prediction Time: 1.0904
# Prediction Time per second: 0.0091
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.7992
# Total Time per second: 0.0150
#
#
#
#
# [3, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1102
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.1717
# Preprocess Time per second: 0.0014
#
#
# Prediction Time: 0.6649
# Prediction Time per second: 0.0055
#
#
# Prediction Time: 1.5631
# Prediction Time per second: 0.0130
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.5099
# Total Time per second: 0.0209
#
#
#
#
# [4, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1174
# Spectrogram Time per second: 0.0010
#
#
# Preprocess Time: 0.1283
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.5673
# Prediction Time per second: 0.0047
#
#
# Prediction Time: 1.4129
# Prediction Time per second: 0.0118
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.2259
# Total Time per second: 0.0185
#
#
#
#
# [5, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1115
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.1157
# Preprocess Time per second: 0.0010
#
#
# Prediction Time: 0.5222
# Prediction Time per second: 0.0044
#
#
# Prediction Time: 1.2916
# Prediction Time per second: 0.0108
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.0410
# Total Time per second: 0.0170
#
#
#
#
# [6, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1064
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.1244
# Preprocess Time per second: 0.0010
#
#
# Prediction Time: 0.5536
# Prediction Time per second: 0.0046
#
#
# Prediction Time: 1.2886
# Prediction Time per second: 0.0107
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 2.0730
# Total Time per second: 0.0173
#
#
#
#
# [7, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0961
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.1073
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.4996
# Prediction Time per second: 0.0042
#
#
# Prediction Time: 1.1212
# Prediction Time per second: 0.0093
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.8242
# Total Time per second: 0.0152
#
#
#
#
# [8, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0981
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.1136
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5247
# Prediction Time per second: 0.0044
#
#
# Prediction Time: 1.0666
# Prediction Time per second: 0.0089
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.8030
# Total Time per second: 0.0150
#
#
#
#
# [9, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0981
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.1081
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5189
# Prediction Time per second: 0.0043
#
#
# Prediction Time: 1.1116
# Prediction Time per second: 0.0093
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.8366
# Total Time per second: 0.0153

# %%
print('CNN: ' + str(np.mean(Times_OD[:,-1,0])))
print('BRNN: ' + str(np.mean(Times_OD[:,-1,1])))
print('RNN: ' + str(np.mean(Times_OD[:,-1,2])))
# Out:
# CNN: 0.029315366347630815
# BRNN: 0.02816485067208608
# RNN: 0.015786938667297364

# %%
print('CNN: ' + str(np.mean(Times_OD[:,-1,0])))
print('BRNN: ' + str(np.mean(Times_OD[:,-1,1])))
print('RNN: ' + str(np.mean(Times_OD[:,-1,2])))
# Out:
# CNN: 0.03049141228199005
# BRNN: 0.02603413045406342
# RNN: 0.01654434204101563

# %%
print('CRNN: ' + str(np.mean(Times_OD[:,-1,0])))
# Out:
# CRNN: 0.013609429200490316
