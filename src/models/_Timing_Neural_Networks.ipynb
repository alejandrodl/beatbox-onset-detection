# %%
import pdb
import time
import numpy as np
import librosa

import tensorflow as tf

from networks import *

# %%
def flatten_sequence(sequence, factor):
    
    seq_length = sequence.shape[-1]
    length = seq_length//factor
    seq_length_diff = seq_length - length

    sequence_flat = np.zeros(tf.size(sequence).numpy()*factor)
    for n in range(len(sequence)):
        point = n*length
        if n==0:
            sequence_flat[:seq_length] = sequence[n]
        else:
            sequence_flat[point:point+seq_length_diff] = sequence_flat[point:point+seq_length_diff] + sequence[n][:-length]
            sequence_flat[point+seq_length_diff:point+seq_length_diff+length] = sequence[n][-length:]

    sequence_flat = sequence_flat[:point+seq_length]
    
    for n in range(factor-1):
        point = n*length
        sequence_flat[point:point+length] = sequence_flat[point:point+length]/(n+1)
        if n==0:
            sequence_flat[-point-length:] = sequence_flat[-point-length:]/(n+1)
        else:
            sequence_flat[-point-length:-point] = sequence_flat[-point-length:-point]/(n+1)
        
    sequence_flat[(factor-1)*length:-(factor-1)*length] = sequence_flat[(factor-1)*length:-(factor-1)*length]/factor
    
    return sequence_flat

# %%
# Onset Detection

num_iter = 20
num_stages = 6

sequence_length = 16
factor_div = 4

Models_OD = ['CNN','RNN','CRNN','Online_RNN']
#Models_OD = ['CRNN']
Times_OD = np.zeros((num_iter,num_stages,len(Models_OD)))

# Preprocess Parameters

hop_size = 128
frame_size = 256

for a in range(len(Models_OD)):

    for N in range(num_iter):

        Model_OD = Models_OD[a]

        print('\n')
        print([N,a])
        print('\n')

        # Onset Detection Parameters

        if Model_OD=='RNN':
            sequence_length = 16
            model = BRNN_1(sequence_length,0)
            hop = 4
        elif Model_OD=='CNN':
            sequence_length = 16
            model = CNN_T_1(sequence_length,0)
            hop = 4
        elif Model_OD=='Online_RNN':
            sequence_length = 10
            model = RNN_1(sequence_length,0)
            hop = 1
        elif Model_OD=='CRNN':
            sequence_length = 16
            model = CRNN_1S_2D(sequence_length,0)
            hop = 1

        # Onset Detection

        audio = np.random.rand(120*22050)

        start = time.time()

        Tensor_All_0 = np.abs(librosa.stft(audio, n_fft=frame_size, hop_length=hop_size, win_length=frame_size, window='hann')).T
        print(Tensor_All_0.shape)
        Tensor_All_0 = np.flipud(Tensor_All_0[:,1:])
        print(Tensor_All_0.shape)

        Time_1 = time.time()-start
        print('Spectrogram Time: {:.4f}'.format(Time_1))
        print('Spectrogram Time per second: {:.4f}'.format(Time_1/(len(audio)/22050)))
        print('\n')
        Times_OD[N,0,a] = Time_1/(len(audio)/22050)
        start = time.time()

        length = Tensor_All_0.shape[0]-sequence_length+1
        Tensor_All = np.zeros(shape=(length,sequence_length,Tensor_All_0.shape[1]))
        for n in range(sequence_length):
            Tensor_All[:,n] = Tensor_All_0[n:length+n]
        if Model_OD!='Online_RNN':
            Tensor_All = Tensor_All[::factor_div]

        Time_2 = time.time()-start
        print('Preprocess Time: {:.4f}'.format(Time_2))
        print('Preprocess Time per second: {:.4f}'.format(Time_2/(len(audio)/22050)))
        print('\n')
        Times_OD[N,1,a] = Time_2/(len(audio)/22050)
        start = time.time()

        Tensor_All = np.log(Tensor_All+1e-4)
        Tensor_All = (Tensor_All-0)/(1-0+1e-16)
        if Model_OD=='CNN' or Model_OD=='CRNN':
            Tensor_All = np.expand_dims(Tensor_All,axis=-1)

        Time_3 = time.time()-start
        print('Prediction Time: {:.4f}'.format(Time_3))
        print('Prediction Time per second: {:.4f}'.format(Time_3/(len(audio)/22050)))
        print('\n')
        Times_OD[N,2,a] = Time_3/(len(audio)/22050)
        if Model_OD=='CRNN':
            Tensor_All = np.random.rand(Tensor_All.shape[0],sequence_length,8,128,1)
        start = time.time()

        predictions = model(Tensor_All)

        Time_4 = time.time()-start
        print('Prediction Time: {:.4f}'.format(Time_4))
        print('Prediction Time per second: {:.4f}'.format(Time_4/(len(audio)/22050)))
        print('\n')
        Times_OD[N,3,a] = Time_4/(len(audio)/22050)
        start = time.time()

        #predictions = model(Tensor_All)
        if Model_OD!='Online_RNN' and Model_OD!='CRNN':
            Prediction = flatten_sequence(tf.math.sigmoid(predictions), factor_div)

        Time_5 = time.time()-start
        print('Prediction Time: {:.4f}'.format(Time_5))
        print('Prediction Time per second: {:.4f}'.format(Time_5/(len(audio)/22050)))
        print('\n')
        Times_OD[N,4,a] = Time_5/(len(audio)/22050)
        start = time.time()

        Time_OD = Time_1 + Time_2 + Time_3 + Time_4
        print('Total Time: {:.4f}'.format(Time_OD))
        print('Total Time per second: {:.4f}'.format(Time_OD/(len(audio)/22050)))
        print('\n')
        Times_OD[N,5,a] = Time_OD/(len(audio)/22050)
# Out:
# [0, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0874
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1982
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2292
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 2.0582
# Prediction Time per second: 0.0172
#
#
# Prediction Time: 2.4531
# Prediction Time per second: 0.0204
#
#
# Total Time: 2.5731
# Total Time per second: 0.0214
#
#
#
#
# [1, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0707
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2017
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2128
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.9374
# Prediction Time per second: 0.0161
#
#
# Prediction Time: 2.4797
# Prediction Time per second: 0.0207
#
#
# Total Time: 2.4225
# Total Time per second: 0.0202
#
#
#
#
# [2, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0713
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1918
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2183
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.9340
# Prediction Time per second: 0.0161
#
#
# Prediction Time: 2.4649
# Prediction Time per second: 0.0205
#
#
# Total Time: 2.4154
# Total Time per second: 0.0201
#
#
#
#
# [3, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0710
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1868
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2021
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.9619
# Prediction Time per second: 0.0163
#
#
# Prediction Time: 2.4271
# Prediction Time per second: 0.0202
#
#
# Total Time: 2.4219
# Total Time per second: 0.0202
#
#
#
#
# [4, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0710
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2100
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2006
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.9444
# Prediction Time per second: 0.0162
#
#
# Prediction Time: 2.5162
# Prediction Time per second: 0.0210
#
#
# Total Time: 2.4260
# Total Time per second: 0.0202
#
#
#
#
# [5, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0723
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1943
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2205
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 2.0221
# Prediction Time per second: 0.0169
#
#
# Prediction Time: 2.4485
# Prediction Time per second: 0.0204
#
#
# Total Time: 2.5092
# Total Time per second: 0.0209
#
#
#
#
# [6, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0712
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1885
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2022
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 2.0109
# Prediction Time per second: 0.0168
#
#
# Prediction Time: 2.4326
# Prediction Time per second: 0.0203
#
#
# Total Time: 2.4727
# Total Time per second: 0.0206
#
#
#
#
# [7, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0727
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1905
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2143
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 2.0243
# Prediction Time per second: 0.0169
#
#
# Prediction Time: 2.5261
# Prediction Time per second: 0.0211
#
#
# Total Time: 2.5019
# Total Time per second: 0.0208
#
#
#
#
# [8, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0724
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1895
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2120
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 2.0217
# Prediction Time per second: 0.0168
#
#
# Prediction Time: 2.4802
# Prediction Time per second: 0.0207
#
#
# Total Time: 2.4956
# Total Time per second: 0.0208
#
#
#
#
# [9, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0730
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1914
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.1983
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.9817
# Prediction Time per second: 0.0165
#
#
# Prediction Time: 2.4625
# Prediction Time per second: 0.0205
#
#
# Total Time: 2.4445
# Total Time per second: 0.0204
#
#
#
#
# [10, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0708
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1952
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2066
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 2.0427
# Prediction Time per second: 0.0170
#
#
# Prediction Time: 2.4270
# Prediction Time per second: 0.0202
#
#
# Total Time: 2.5153
# Total Time per second: 0.0210
#
#
#
#
# [11, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0720
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1932
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2086
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 2.1020
# Prediction Time per second: 0.0175
#
#
# Prediction Time: 2.4650
# Prediction Time per second: 0.0205
#
#
# Total Time: 2.5758
# Total Time per second: 0.0215
#
#
#
#
# [12, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0743
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1875
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2065
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 2.0786
# Prediction Time per second: 0.0173
#
#
# Prediction Time: 2.4362
# Prediction Time per second: 0.0203
#
#
# Total Time: 2.5469
# Total Time per second: 0.0212
#
#
#
#
# [13, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0716
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1881
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2132
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 2.0855
# Prediction Time per second: 0.0174
#
#
# Prediction Time: 2.4382
# Prediction Time per second: 0.0203
#
#
# Total Time: 2.5583
# Total Time per second: 0.0213
#
#
#
#
# [14, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0723
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1987
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2024
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 2.0832
# Prediction Time per second: 0.0174
#
#
# Prediction Time: 2.4663
# Prediction Time per second: 0.0206
#
#
# Total Time: 2.5566
# Total Time per second: 0.0213
#
#
#
#
# [15, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0713
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1960
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2073
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 2.0499
# Prediction Time per second: 0.0171
#
#
# Prediction Time: 2.4796
# Prediction Time per second: 0.0207
#
#
# Total Time: 2.5244
# Total Time per second: 0.0210
#
#
#
#
# [16, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0712
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1886
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2013
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 2.0444
# Prediction Time per second: 0.0170
#
#
# Prediction Time: 2.4949
# Prediction Time per second: 0.0208
#
#
# Total Time: 2.5055
# Total Time per second: 0.0209
#
#
#
#
# [17, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0725
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1931
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.1987
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 2.0287
# Prediction Time per second: 0.0169
#
#
# Prediction Time: 2.4424
# Prediction Time per second: 0.0204
#
#
# Total Time: 2.4930
# Total Time per second: 0.0208
#
#
#
#
# [18, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0748
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2016
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.2154
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 2.0721
# Prediction Time per second: 0.0173
#
#
# Prediction Time: 2.4681
# Prediction Time per second: 0.0206
#
#
# Total Time: 2.5638
# Total Time per second: 0.0214
#
#
#
#
# [19, 0]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0739
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1955
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2051
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 2.1294
# Prediction Time per second: 0.0177
#
#
# Prediction Time: 2.4352
# Prediction Time per second: 0.0203
#
#
# Total Time: 2.6039
# Total Time per second: 0.0217
#
#
#
#
# [0, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0875
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1878
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.1981
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.2440
# Prediction Time per second: 0.0104
#
#
# Prediction Time: 2.4289
# Prediction Time per second: 0.0202
#
#
# Total Time: 1.7174
# Total Time per second: 0.0143
#
#
#
#
# [1, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0748
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1906
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2034
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.2689
# Prediction Time per second: 0.0106
#
#
# Prediction Time: 2.4822
# Prediction Time per second: 0.0207
#
#
# Total Time: 1.7376
# Total Time per second: 0.0145
#
#
#
#
# [2, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0592
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.1881
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2023
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.2087
# Prediction Time per second: 0.0101
#
#
# Prediction Time: 2.4563
# Prediction Time per second: 0.0205
#
#
# Total Time: 1.6583
# Total Time per second: 0.0138
#
#
#
#
# [3, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0623
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.1868
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2080
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.2152
# Prediction Time per second: 0.0101
#
#
# Prediction Time: 2.4706
# Prediction Time per second: 0.0206
#
#
# Total Time: 1.6723
# Total Time per second: 0.0139
#
#
#
#
# [4, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0745
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1884
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2105
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.2667
# Prediction Time per second: 0.0106
#
#
# Prediction Time: 2.4596
# Prediction Time per second: 0.0205
#
#
# Total Time: 1.7400
# Total Time per second: 0.0145
#
#
#
#
# [5, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0740
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1861
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2005
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.2111
# Prediction Time per second: 0.0101
#
#
# Prediction Time: 2.4365
# Prediction Time per second: 0.0203
#
#
# Total Time: 1.6717
# Total Time per second: 0.0139
#
#
#
#
# [6, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0781
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1901
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2126
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.1954
# Prediction Time per second: 0.0100
#
#
# Prediction Time: 2.4478
# Prediction Time per second: 0.0204
#
#
# Total Time: 1.6763
# Total Time per second: 0.0140
#
#
#
#
# [7, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0734
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1890
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2127
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.1894
# Prediction Time per second: 0.0099
#
#
# Prediction Time: 2.4491
# Prediction Time per second: 0.0204
#
#
# Total Time: 1.6646
# Total Time per second: 0.0139
#
#
#
#
# [8, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0743
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1844
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.2099
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.2376
# Prediction Time per second: 0.0103
#
#
# Prediction Time: 2.4550
# Prediction Time per second: 0.0205
#
#
# Total Time: 1.7062
# Total Time per second: 0.0142
#
#
#
#
# [9, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0740
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1855
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.2067
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.2578
# Prediction Time per second: 0.0105
#
#
# Prediction Time: 2.4489
# Prediction Time per second: 0.0204
#
#
# Total Time: 1.7239
# Total Time per second: 0.0144
#
#
#
#
# [10, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0733
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1819
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.2059
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.1863
# Prediction Time per second: 0.0099
#
#
# Prediction Time: 2.4659
# Prediction Time per second: 0.0205
#
#
# Total Time: 1.6474
# Total Time per second: 0.0137
#
#
#
#
# [11, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0746
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1903
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2050
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.1992
# Prediction Time per second: 0.0100
#
#
# Prediction Time: 2.4745
# Prediction Time per second: 0.0206
#
#
# Total Time: 1.6690
# Total Time per second: 0.0139
#
#
#
#
# [12, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0753
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1890
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2072
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.1984
# Prediction Time per second: 0.0100
#
#
# Prediction Time: 2.4683
# Prediction Time per second: 0.0206
#
#
# Total Time: 1.6699
# Total Time per second: 0.0139
#
#
#
#
# [13, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0757
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1979
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2123
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.2046
# Prediction Time per second: 0.0100
#
#
# Prediction Time: 2.7823
# Prediction Time per second: 0.0232
#
#
# Total Time: 1.6905
# Total Time per second: 0.0141
#
#
#
#
# [14, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0749
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1949
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2079
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.3064
# Prediction Time per second: 0.0109
#
#
# Prediction Time: 2.5205
# Prediction Time per second: 0.0210
#
#
# Total Time: 1.7841
# Total Time per second: 0.0149
#
#
#
#
# [15, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0750
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1971
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2136
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.2542
# Prediction Time per second: 0.0105
#
#
# Prediction Time: 2.5293
# Prediction Time per second: 0.0211
#
#
# Total Time: 1.7399
# Total Time per second: 0.0145
#
#
#
#
# [16, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0754
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1937
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2109
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.2138
# Prediction Time per second: 0.0101
#
#
# Prediction Time: 2.4509
# Prediction Time per second: 0.0204
#
#
# Total Time: 1.6939
# Total Time per second: 0.0141
#
#
#
#
# [17, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0734
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1936
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2121
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.2995
# Prediction Time per second: 0.0108
#
#
# Prediction Time: 2.4682
# Prediction Time per second: 0.0206
#
#
# Total Time: 1.7786
# Total Time per second: 0.0148
#
#
#
#
# [18, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0742
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1918
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2086
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.2464
# Prediction Time per second: 0.0104
#
#
# Prediction Time: 2.4550
# Prediction Time per second: 0.0205
#
#
# Total Time: 1.7209
# Total Time per second: 0.0143
#
#
#
#
# [19, 1]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0737
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1961
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2156
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.2379
# Prediction Time per second: 0.0103
#
#
# Prediction Time: 2.4591
# Prediction Time per second: 0.0205
#
#
# Total Time: 1.7234
# Total Time per second: 0.0144
#
#
#
#
# [0, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0758
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.1947
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.2134
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 13.2043
# Prediction Time per second: 0.1100
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 13.6883
# Total Time per second: 0.1141
#
#
#
#
# [1, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0666
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2336
# Preprocess Time per second: 0.0019
#
#
# Prediction Time: 0.2069
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 13.9750
# Prediction Time per second: 0.1165
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 14.4820
# Total Time per second: 0.1207
#
#
#
#
# [2, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0749
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2343
# Preprocess Time per second: 0.0020
#
#
# Prediction Time: 0.2408
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 13.9709
# Prediction Time per second: 0.1164
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 14.5208
# Total Time per second: 0.1210
#
#
#
#
# [3, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0786
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.2263
# Preprocess Time per second: 0.0019
#
#
# Prediction Time: 0.2074
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 14.0837
# Prediction Time per second: 0.1174
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 14.5960
# Total Time per second: 0.1216
#
#
#
#
# [4, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0650
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.2214
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2026
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 14.2079
# Prediction Time per second: 0.1184
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 14.6969
# Total Time per second: 0.1225
#
#
#
#
# [5, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0679
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2283
# Preprocess Time per second: 0.0019
#
#
# Prediction Time: 0.2065
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 14.1946
# Prediction Time per second: 0.1183
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 14.6972
# Total Time per second: 0.1225
#
#
#
#
# [6, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0630
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.2230
# Preprocess Time per second: 0.0019
#
#
# Prediction Time: 0.2042
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 14.1440
# Prediction Time per second: 0.1179
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 14.6342
# Total Time per second: 0.1220
#
#
#
#
# [7, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0783
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.2231
# Preprocess Time per second: 0.0019
#
#
# Prediction Time: 0.2450
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 14.1108
# Prediction Time per second: 0.1176
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 14.6571
# Total Time per second: 0.1221
#
#
#
#
# [8, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0796
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.2198
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2075
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 14.2352
# Prediction Time per second: 0.1186
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 14.7421
# Total Time per second: 0.1229
#
#
#
#
# [9, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0693
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2208
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2023
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 14.1698
# Prediction Time per second: 0.1181
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 14.6622
# Total Time per second: 0.1222
#
#
#
#
# [10, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0631
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.2191
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.2077
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 14.4293
# Prediction Time per second: 0.1202
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 14.9192
# Total Time per second: 0.1243
#
#
#
#
# [11, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0805
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.2246
# Preprocess Time per second: 0.0019
#
#
# Prediction Time: 0.2359
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 14.7683
# Prediction Time per second: 0.1231
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 15.3092
# Total Time per second: 0.1276
#
#
#
#
# [12, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0841
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.2367
# Preprocess Time per second: 0.0020
#
#
# Prediction Time: 0.2107
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 14.9807
# Prediction Time per second: 0.1248
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 15.5122
# Total Time per second: 0.1293
#
#
#
#
# [13, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0704
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2391
# Preprocess Time per second: 0.0020
#
#
# Prediction Time: 0.2102
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 15.5105
# Prediction Time per second: 0.1293
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 16.0303
# Total Time per second: 0.1336
#
#
#
#
# [14, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0769
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2529
# Preprocess Time per second: 0.0021
#
#
# Prediction Time: 0.2288
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 15.6669
# Prediction Time per second: 0.1306
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 16.2255
# Total Time per second: 0.1352
#
#
#
#
# [15, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0706
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2470
# Preprocess Time per second: 0.0021
#
#
# Prediction Time: 0.2209
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 15.8113
# Prediction Time per second: 0.1318
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 16.3498
# Total Time per second: 0.1362
#
#
#
#
# [16, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0858
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.2372
# Preprocess Time per second: 0.0020
#
#
# Prediction Time: 0.2385
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 15.6137
# Prediction Time per second: 0.1301
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 16.1752
# Total Time per second: 0.1348
#
#
#
#
# [17, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0881
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.2407
# Preprocess Time per second: 0.0020
#
#
# Prediction Time: 0.2212
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 15.4917
# Prediction Time per second: 0.1291
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 16.0417
# Total Time per second: 0.1337
#
#
#
#
# [18, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0709
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2320
# Preprocess Time per second: 0.0019
#
#
# Prediction Time: 0.2110
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 15.7146
# Prediction Time per second: 0.1310
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 16.2284
# Total Time per second: 0.1352
#
#
#
#
# [19, 2]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0711
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.2471
# Preprocess Time per second: 0.0021
#
#
# Prediction Time: 0.2211
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 15.3157
# Prediction Time per second: 0.1276
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 15.8550
# Total Time per second: 0.1321
#
#
#
#
# [0, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0843
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1522
# Preprocess Time per second: 0.0013
#
#
# Prediction Time: 0.5301
# Prediction Time per second: 0.0044
#
#
# Prediction Time: 0.3054
# Prediction Time per second: 0.0025
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.0720
# Total Time per second: 0.0089
#
#
#
#
# [1, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0784
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1101
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5116
# Prediction Time per second: 0.0043
#
#
# Prediction Time: 0.2500
# Prediction Time per second: 0.0021
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9501
# Total Time per second: 0.0079
#
#
#
#
# [2, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0968
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.1109
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.4742
# Prediction Time per second: 0.0040
#
#
# Prediction Time: 0.2659
# Prediction Time per second: 0.0022
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9478
# Total Time per second: 0.0079
#
#
#
#
# [3, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0829
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1046
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5017
# Prediction Time per second: 0.0042
#
#
# Prediction Time: 0.2308
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9200
# Total Time per second: 0.0077
#
#
#
#
# [4, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.1015
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.1311
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.4964
# Prediction Time per second: 0.0041
#
#
# Prediction Time: 0.2329
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9618
# Total Time per second: 0.0080
#
#
#
#
# [5, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0847
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1105
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5136
# Prediction Time per second: 0.0043
#
#
# Prediction Time: 0.2385
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9472
# Total Time per second: 0.0079
#
#
#
#
# [6, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0877
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1105
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5006
# Prediction Time per second: 0.0042
#
#
# Prediction Time: 0.2322
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9309
# Total Time per second: 0.0078
#
#
#
#
# [7, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0828
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1093
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5004
# Prediction Time per second: 0.0042
#
#
# Prediction Time: 0.2321
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9246
# Total Time per second: 0.0077
#
#
#
#
# [8, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0840
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1096
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.4951
# Prediction Time per second: 0.0041
#
#
# Prediction Time: 0.2275
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9162
# Total Time per second: 0.0076
#
#
#
#
# [9, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0865
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1069
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.4932
# Prediction Time per second: 0.0041
#
#
# Prediction Time: 0.2255
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9121
# Total Time per second: 0.0076
#
#
#
#
# [10, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0867
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1067
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5173
# Prediction Time per second: 0.0043
#
#
# Prediction Time: 0.2343
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9450
# Total Time per second: 0.0079
#
#
#
#
# [11, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0831
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1062
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.4948
# Prediction Time per second: 0.0041
#
#
# Prediction Time: 0.2319
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9160
# Total Time per second: 0.0076
#
#
#
#
# [12, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0858
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1079
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5031
# Prediction Time per second: 0.0042
#
#
# Prediction Time: 0.2349
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9317
# Total Time per second: 0.0078
#
#
#
#
# [13, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0834
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1062
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.4963
# Prediction Time per second: 0.0041
#
#
# Prediction Time: 0.2321
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9179
# Total Time per second: 0.0076
#
#
#
#
# [14, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0816
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1072
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.4848
# Prediction Time per second: 0.0040
#
#
# Prediction Time: 0.2324
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9059
# Total Time per second: 0.0075
#
#
#
#
# [15, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0869
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1071
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.4923
# Prediction Time per second: 0.0041
#
#
# Prediction Time: 0.2316
# Prediction Time per second: 0.0019
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9180
# Total Time per second: 0.0077
#
#
#
#
# [16, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0880
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1071
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5297
# Prediction Time per second: 0.0044
#
#
# Prediction Time: 0.2357
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9606
# Total Time per second: 0.0080
#
#
#
#
# [17, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0875
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1130
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5313
# Prediction Time per second: 0.0044
#
#
# Prediction Time: 0.2356
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9674
# Total Time per second: 0.0081
#
#
#
#
# [18, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0844
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1069
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5117
# Prediction Time per second: 0.0043
#
#
# Prediction Time: 0.2354
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9384
# Total Time per second: 0.0078
#
#
#
#
# [19, 3]
#
#
# (20672, 129)
# (20672, 128)
# Spectrogram Time: 0.0862
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.1067
# Preprocess Time per second: 0.0009
#
#
# Prediction Time: 0.5261
# Prediction Time per second: 0.0044
#
#
# Prediction Time: 0.2421
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.9610
# Total Time per second: 0.0080

# %%
print('CNN: ' + str(np.mean(Times_OD[:,-1,0])) + ' +- ' + str(np.std(Times_OD[:,-1,0])) + '|' + str(np.std(Times_OD[:,-1,0])*0.43826932358995874))
print('RNN: ' + str(np.mean(Times_OD[:,-1,1])) + ' +- ' + str(np.std(Times_OD[:,-1,1])) + '|' + str(np.std(Times_OD[:,-1,1])*0.43826932358995874))
print('CRNN: ' + str(np.mean(Times_OD[:,-1,2])) + ' +- ' + str(np.std(Times_OD[:,-1,2])) + '|' + str(np.std(Times_OD[:,-1,2])*0.43826932358995874))
print('Online_RNN: ' + str(np.mean(Times_OD[:,-1,3])) + ' +- ' + str(np.std(Times_OD[:,-1,3])) + '|' + str(np.std(Times_OD[:,-1,3])*0.43826932358995874))
# MKL: 0.010587399303913116 +- 0.00016365101657776944|7.172322034034813e-05
# Out:
# CNN: 0.020885973175366716 +- 0.0004697723257743631|0.00020588679945841184
# RNN: 0.014202524721622464 +- 0.00031882290951794405|0.00013973030089941196
# CRNN: 0.12667637636264167 +- 0.006358427621735013|0.002786703772873514
# Online_RNN: 0.007851984103520712 +- 0.00029159350514345304|0.00012779648826244632

# %%
(1.96/5)*74
# Out:
# 29.008000000000003

# %%
# Onset Detection

num_iter = 20
num_stages = 6

sequence_length = 16
factor_div = 4

Models_OD = ['CNN','RNN','CRNN','Online_RNN']
#Models_OD = ['CRNN']
Times_OD = np.zeros((num_iter,num_stages,len(Models_OD)))

# Preprocess Parameters

hop_size = 128
frame_size = 256

for a in range(len(Models_OD)):

    for N in range(num_iter):

        Model_OD = Models_OD[a]

        print('\n')
        print([N,a])
        print('\n')

        # Onset Detection Parameters

        if Model_OD=='RNN':
            sequence_length = 16
            model = BRNN_1(sequence_length,0)
            hop = 4
        elif Model_OD=='CNN':
            sequence_length = 16
            model = CNN_T_1(sequence_length,0)
            hop = 4
        elif Model_OD=='Online_RNN':
            sequence_length = 10
            model = RNN_1(sequence_length,0)
            hop = 1
        elif Model_OD=='CRNN':
            sequence_length = 16
            model = CRNN_1S_2D(sequence_length,0)
            hop = 1

        # Onset Detection

        audio = np.random.rand(10*22050)

        start = time.time()

        Tensor_All_0 = np.abs(librosa.stft(audio, n_fft=frame_size, hop_length=hop_size, win_length=frame_size, window='hann')).T
        print(Tensor_All_0.shape)
        Tensor_All_0 = np.flipud(Tensor_All_0[:,1:])
        print(Tensor_All_0.shape)

        Time_1 = time.time()-start
        print('Spectrogram Time: {:.4f}'.format(Time_1))
        print('Spectrogram Time per second: {:.4f}'.format(Time_1/(len(audio)/22050)))
        print('\n')
        Times_OD[N,0,a] = Time_1/(len(audio)/22050)
        start = time.time()

        length = Tensor_All_0.shape[0]-sequence_length+1
        Tensor_All = np.zeros(shape=(length,sequence_length,Tensor_All_0.shape[1]))
        for n in range(sequence_length):
            Tensor_All[:,n] = Tensor_All_0[n:length+n]
        if Model_OD!='Online_RNN':
            Tensor_All = Tensor_All[::factor_div]

        Time_2 = time.time()-start
        print('Preprocess Time: {:.4f}'.format(Time_2))
        print('Preprocess Time per second: {:.4f}'.format(Time_2/(len(audio)/22050)))
        print('\n')
        Times_OD[N,1,a] = Time_2/(len(audio)/22050)
        start = time.time()

        Tensor_All = np.log(Tensor_All+1e-4)
        Tensor_All = (Tensor_All-0)/(1-0+1e-16)
        if Model_OD=='CNN' or Model_OD=='CRNN':
            Tensor_All = np.expand_dims(Tensor_All,axis=-1)

        Time_3 = time.time()-start
        print('Prediction Time: {:.4f}'.format(Time_3))
        print('Prediction Time per second: {:.4f}'.format(Time_3/(len(audio)/22050)))
        print('\n')
        Times_OD[N,2,a] = Time_3/(len(audio)/22050)
        if Model_OD=='CRNN':
            Tensor_All = np.random.rand(Tensor_All.shape[0],sequence_length,8,128,1)
        start = time.time()

        predictions = model(Tensor_All)

        Time_4 = time.time()-start
        print('Prediction Time: {:.4f}'.format(Time_4))
        print('Prediction Time per second: {:.4f}'.format(Time_4/(len(audio)/22050)))
        print('\n')
        Times_OD[N,3,a] = Time_4/(len(audio)/22050)
        start = time.time()

        #predictions = model(Tensor_All)
        if Model_OD!='Online_RNN' and Model_OD!='CRNN':
            Prediction = flatten_sequence(tf.math.sigmoid(predictions), factor_div)

        Time_5 = time.time()-start
        print('Prediction Time: {:.4f}'.format(Time_5))
        print('Prediction Time per second: {:.4f}'.format(Time_5/(len(audio)/22050)))
        print('\n')
        Times_OD[N,4,a] = Time_5/(len(audio)/22050)
        start = time.time()

        Time_OD = Time_1 + Time_2 + Time_3 + Time_4
        print('Total Time: {:.4f}'.format(Time_OD))
        print('Total Time per second: {:.4f}'.format(Time_OD/(len(audio)/22050)))
        print('\n')
        Times_OD[N,5,a] = Time_OD/(len(audio)/22050)
# Out:
# [0, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0119
# Spectrogram Time per second: 0.0012
#
#
# Preprocess Time: 0.0194
# Preprocess Time per second: 0.0019
#
#
# Prediction Time: 0.0294
# Prediction Time per second: 0.0029
#
#
# Prediction Time: 0.5336
# Prediction Time per second: 0.0534
#
#
# Prediction Time: 0.2886
# Prediction Time per second: 0.0289
#
#
# Total Time: 0.5943
# Total Time per second: 0.0594
#
#
#
#
# [1, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0071
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0162
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0168
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.2421
# Prediction Time per second: 0.0242
#
#
# Prediction Time: 0.2357
# Prediction Time per second: 0.0236
#
#
# Total Time: 0.2822
# Total Time per second: 0.0282
#
#
#
#
# [2, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0097
# Spectrogram Time per second: 0.0010
#
#
# Preprocess Time: 0.0155
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0164
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 0.2533
# Prediction Time per second: 0.0253
#
#
# Prediction Time: 0.2188
# Prediction Time per second: 0.0219
#
#
# Total Time: 0.2949
# Total Time per second: 0.0295
#
#
#
#
# [3, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0089
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.0147
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0162
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 0.2262
# Prediction Time per second: 0.0226
#
#
# Prediction Time: 0.2743
# Prediction Time per second: 0.0274
#
#
# Total Time: 0.2659
# Total Time per second: 0.0266
#
#
#
#
# [4, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0099
# Spectrogram Time per second: 0.0010
#
#
# Preprocess Time: 0.0248
# Preprocess Time per second: 0.0025
#
#
# Prediction Time: 0.0215
# Prediction Time per second: 0.0022
#
#
# Prediction Time: 0.2881
# Prediction Time per second: 0.0288
#
#
# Prediction Time: 0.2815
# Prediction Time per second: 0.0282
#
#
# Total Time: 0.3443
# Total Time per second: 0.0344
#
#
#
#
# [5, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0095
# Spectrogram Time per second: 0.0010
#
#
# Preprocess Time: 0.0160
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0155
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 0.2511
# Prediction Time per second: 0.0251
#
#
# Prediction Time: 0.2162
# Prediction Time per second: 0.0216
#
#
# Total Time: 0.2922
# Total Time per second: 0.0292
#
#
#
#
# [6, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0072
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0159
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0165
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.2468
# Prediction Time per second: 0.0247
#
#
# Prediction Time: 0.2322
# Prediction Time per second: 0.0232
#
#
# Total Time: 0.2864
# Total Time per second: 0.0286
#
#
#
#
# [7, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0083
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0151
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0184
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 0.3205
# Prediction Time per second: 0.0321
#
#
# Prediction Time: 0.2472
# Prediction Time per second: 0.0247
#
#
# Total Time: 0.3623
# Total Time per second: 0.0362
#
#
#
#
# [8, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0088
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.0179
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.0154
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 0.2284
# Prediction Time per second: 0.0228
#
#
# Prediction Time: 0.2206
# Prediction Time per second: 0.0221
#
#
# Total Time: 0.2704
# Total Time per second: 0.0270
#
#
#
#
# [9, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0085
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0213
# Preprocess Time per second: 0.0021
#
#
# Prediction Time: 0.0214
# Prediction Time per second: 0.0021
#
#
# Prediction Time: 0.2398
# Prediction Time per second: 0.0240
#
#
# Prediction Time: 0.2194
# Prediction Time per second: 0.0219
#
#
# Total Time: 0.2910
# Total Time per second: 0.0291
#
#
#
#
# [10, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0102
# Spectrogram Time per second: 0.0010
#
#
# Preprocess Time: 0.0148
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0146
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 0.2342
# Prediction Time per second: 0.0234
#
#
# Prediction Time: 0.2196
# Prediction Time per second: 0.0220
#
#
# Total Time: 0.2738
# Total Time per second: 0.0274
#
#
#
#
# [11, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0119
# Spectrogram Time per second: 0.0012
#
#
# Preprocess Time: 0.0151
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0167
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.2349
# Prediction Time per second: 0.0235
#
#
# Prediction Time: 0.2355
# Prediction Time per second: 0.0235
#
#
# Total Time: 0.2785
# Total Time per second: 0.0278
#
#
#
#
# [12, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0080
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0163
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0169
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.2357
# Prediction Time per second: 0.0236
#
#
# Prediction Time: 0.2372
# Prediction Time per second: 0.0237
#
#
# Total Time: 0.2769
# Total Time per second: 0.0277
#
#
#
#
# [13, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0072
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0161
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0169
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.2376
# Prediction Time per second: 0.0238
#
#
# Prediction Time: 0.2170
# Prediction Time per second: 0.0217
#
#
# Total Time: 0.2778
# Total Time per second: 0.0278
#
#
#
#
# [14, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0100
# Spectrogram Time per second: 0.0010
#
#
# Preprocess Time: 0.0149
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0150
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 0.2426
# Prediction Time per second: 0.0243
#
#
# Prediction Time: 0.2249
# Prediction Time per second: 0.0225
#
#
# Total Time: 0.2826
# Total Time per second: 0.0283
#
#
#
#
# [15, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0093
# Spectrogram Time per second: 0.0009
#
#
# Preprocess Time: 0.0151
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0157
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 0.2595
# Prediction Time per second: 0.0259
#
#
# Prediction Time: 0.2582
# Prediction Time per second: 0.0258
#
#
# Total Time: 0.2997
# Total Time per second: 0.0300
#
#
#
#
# [16, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0081
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0159
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0165
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.2804
# Prediction Time per second: 0.0280
#
#
# Prediction Time: 0.2154
# Prediction Time per second: 0.0215
#
#
# Total Time: 0.3209
# Total Time per second: 0.0321
#
#
#
#
# [17, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0061
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.0154
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0161
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 0.2355
# Prediction Time per second: 0.0236
#
#
# Prediction Time: 0.2163
# Prediction Time per second: 0.0216
#
#
# Total Time: 0.2732
# Total Time per second: 0.0273
#
#
#
#
# [18, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0096
# Spectrogram Time per second: 0.0010
#
#
# Preprocess Time: 0.0144
# Preprocess Time per second: 0.0014
#
#
# Prediction Time: 0.0160
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 0.2340
# Prediction Time per second: 0.0234
#
#
# Prediction Time: 0.2404
# Prediction Time per second: 0.0240
#
#
# Total Time: 0.2740
# Total Time per second: 0.0274
#
#
#
#
# [19, 0]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0103
# Spectrogram Time per second: 0.0010
#
#
# Preprocess Time: 0.0149
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0149
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 0.2731
# Prediction Time per second: 0.0273
#
#
# Prediction Time: 0.2348
# Prediction Time per second: 0.0235
#
#
# Total Time: 0.3132
# Total Time per second: 0.0313
#
#
#
#
# [0, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0085
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0158
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0167
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.1938
# Prediction Time per second: 0.0194
#
#
# Prediction Time: 0.2134
# Prediction Time per second: 0.0213
#
#
# Total Time: 0.2348
# Total Time per second: 0.0235
#
#
#
#
# [1, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0052
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0163
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0173
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.1896
# Prediction Time per second: 0.0190
#
#
# Prediction Time: 0.2281
# Prediction Time per second: 0.0228
#
#
# Total Time: 0.2284
# Total Time per second: 0.0228
#
#
#
#
# [2, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0055
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0162
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0165
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.1842
# Prediction Time per second: 0.0184
#
#
# Prediction Time: 0.2242
# Prediction Time per second: 0.0224
#
#
# Total Time: 0.2225
# Total Time per second: 0.0222
#
#
#
#
# [3, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0053
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0161
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0167
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.3004
# Prediction Time per second: 0.0300
#
#
# Prediction Time: 0.2813
# Prediction Time per second: 0.0281
#
#
# Total Time: 0.3385
# Total Time per second: 0.0338
#
#
#
#
# [4, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0069
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0155
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0146
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 0.1886
# Prediction Time per second: 0.0189
#
#
# Prediction Time: 0.2142
# Prediction Time per second: 0.0214
#
#
# Total Time: 0.2256
# Total Time per second: 0.0226
#
#
#
#
# [5, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0050
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0157
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0182
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 0.1910
# Prediction Time per second: 0.0191
#
#
# Prediction Time: 0.2379
# Prediction Time per second: 0.0238
#
#
# Total Time: 0.2300
# Total Time per second: 0.0230
#
#
#
#
# [6, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0061
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.0167
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.0167
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.1860
# Prediction Time per second: 0.0186
#
#
# Prediction Time: 0.2215
# Prediction Time per second: 0.0221
#
#
# Total Time: 0.2254
# Total Time per second: 0.0225
#
#
#
#
# [7, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0082
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0151
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0166
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.2185
# Prediction Time per second: 0.0218
#
#
# Prediction Time: 0.2190
# Prediction Time per second: 0.0219
#
#
# Total Time: 0.2584
# Total Time per second: 0.0258
#
#
#
#
# [8, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0081
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0169
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.0169
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.1887
# Prediction Time per second: 0.0189
#
#
# Prediction Time: 0.2177
# Prediction Time per second: 0.0218
#
#
# Total Time: 0.2306
# Total Time per second: 0.0231
#
#
#
#
# [9, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0064
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.0153
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0153
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 0.1861
# Prediction Time per second: 0.0186
#
#
# Prediction Time: 0.2290
# Prediction Time per second: 0.0229
#
#
# Total Time: 0.2230
# Total Time per second: 0.0223
#
#
#
#
# [10, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0053
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0176
# Preprocess Time per second: 0.0018
#
#
# Prediction Time: 0.0173
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.1970
# Prediction Time per second: 0.0197
#
#
# Prediction Time: 0.2323
# Prediction Time per second: 0.0232
#
#
# Total Time: 0.2372
# Total Time per second: 0.0237
#
#
#
#
# [11, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0063
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.0171
# Preprocess Time per second: 0.0017
#
#
# Prediction Time: 0.0165
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.1861
# Prediction Time per second: 0.0186
#
#
# Prediction Time: 0.2152
# Prediction Time per second: 0.0215
#
#
# Total Time: 0.2260
# Total Time per second: 0.0226
#
#
#
#
# [12, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0084
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0149
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0164
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 0.1892
# Prediction Time per second: 0.0189
#
#
# Prediction Time: 0.3119
# Prediction Time per second: 0.0312
#
#
# Total Time: 0.2289
# Total Time per second: 0.0229
#
#
#
#
# [13, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0074
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0158
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0151
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 0.1854
# Prediction Time per second: 0.0185
#
#
# Prediction Time: 0.2340
# Prediction Time per second: 0.0234
#
#
# Total Time: 0.2237
# Total Time per second: 0.0224
#
#
#
#
# [14, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0050
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0155
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0172
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.1872
# Prediction Time per second: 0.0187
#
#
# Prediction Time: 0.2150
# Prediction Time per second: 0.0215
#
#
# Total Time: 0.2248
# Total Time per second: 0.0225
#
#
#
#
# [15, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0055
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.0154
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0171
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.1855
# Prediction Time per second: 0.0186
#
#
# Prediction Time: 0.2191
# Prediction Time per second: 0.0219
#
#
# Total Time: 0.2236
# Total Time per second: 0.0224
#
#
#
#
# [16, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0077
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0160
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0159
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 0.1852
# Prediction Time per second: 0.0185
#
#
# Prediction Time: 0.2192
# Prediction Time per second: 0.0219
#
#
# Total Time: 0.2248
# Total Time per second: 0.0225
#
#
#
#
# [17, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0078
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0156
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0158
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 0.1831
# Prediction Time per second: 0.0183
#
#
# Prediction Time: 0.2940
# Prediction Time per second: 0.0294
#
#
# Total Time: 0.2224
# Total Time per second: 0.0222
#
#
#
#
# [18, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0063
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.0148
# Preprocess Time per second: 0.0015
#
#
# Prediction Time: 0.0149
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 0.1839
# Prediction Time per second: 0.0184
#
#
# Prediction Time: 0.2122
# Prediction Time per second: 0.0212
#
#
# Total Time: 0.2199
# Total Time per second: 0.0220
#
#
#
#
# [19, 1]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0053
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0158
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0171
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 0.1826
# Prediction Time per second: 0.0183
#
#
# Prediction Time: 0.2293
# Prediction Time per second: 0.0229
#
#
# Total Time: 0.2208
# Total Time per second: 0.0221
#
#
#
#
# [0, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0055
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0162
# Preprocess Time per second: 0.0016
#
#
# Prediction Time: 0.0164
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 1.4562
# Prediction Time per second: 0.1456
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.4942
# Total Time per second: 0.1494
#
#
#
#
# [1, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0051
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0114
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.0159
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 1.3741
# Prediction Time per second: 0.1374
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.4066
# Total Time per second: 0.1407
#
#
#
#
# [2, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0102
# Spectrogram Time per second: 0.0010
#
#
# Preprocess Time: 0.0277
# Preprocess Time per second: 0.0028
#
#
# Prediction Time: 0.0200
# Prediction Time per second: 0.0020
#
#
# Prediction Time: 1.3237
# Prediction Time per second: 0.1324
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3816
# Total Time per second: 0.1382
#
#
#
#
# [3, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0076
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0103
# Preprocess Time per second: 0.0010
#
#
# Prediction Time: 0.0151
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.3301
# Prediction Time per second: 0.1330
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3632
# Total Time per second: 0.1363
#
#
#
#
# [4, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0051
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0102
# Preprocess Time per second: 0.0010
#
#
# Prediction Time: 0.0155
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 1.3068
# Prediction Time per second: 0.1307
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3376
# Total Time per second: 0.1338
#
#
#
#
# [5, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0047
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0108
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.0148
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.3189
# Prediction Time per second: 0.1319
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3493
# Total Time per second: 0.1349
#
#
#
#
# [6, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0050
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0109
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.0152
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.3121
# Prediction Time per second: 0.1312
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3431
# Total Time per second: 0.1343
#
#
#
#
# [7, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0070
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0199
# Preprocess Time per second: 0.0020
#
#
# Prediction Time: 0.0184
# Prediction Time per second: 0.0018
#
#
# Prediction Time: 1.3283
# Prediction Time per second: 0.1328
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3736
# Total Time per second: 0.1374
#
#
#
#
# [8, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0073
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0108
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.0155
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 1.3720
# Prediction Time per second: 0.1372
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.4057
# Total Time per second: 0.1406
#
#
#
#
# [9, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0049
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0112
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.0151
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.3487
# Prediction Time per second: 0.1349
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3800
# Total Time per second: 0.1380
#
#
#
#
# [10, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0055
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0102
# Preprocess Time per second: 0.0010
#
#
# Prediction Time: 0.0152
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.3255
# Prediction Time per second: 0.1325
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3564
# Total Time per second: 0.1356
#
#
#
#
# [11, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0077
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0199
# Preprocess Time per second: 0.0020
#
#
# Prediction Time: 0.0173
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.3000
# Prediction Time per second: 0.1300
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3450
# Total Time per second: 0.1345
#
#
#
#
# [12, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0067
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0123
# Preprocess Time per second: 0.0012
#
#
# Prediction Time: 0.0163
# Prediction Time per second: 0.0016
#
#
# Prediction Time: 1.3338
# Prediction Time per second: 0.1334
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3692
# Total Time per second: 0.1369
#
#
#
#
# [13, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0055
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0110
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.0153
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.4369
# Prediction Time per second: 0.1437
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.4688
# Total Time per second: 0.1469
#
#
#
#
# [14, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0051
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0099
# Preprocess Time per second: 0.0010
#
#
# Prediction Time: 0.0151
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.2819
# Prediction Time per second: 0.1282
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3120
# Total Time per second: 0.1312
#
#
#
#
# [15, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0049
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0112
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.0151
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.3550
# Prediction Time per second: 0.1355
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3862
# Total Time per second: 0.1386
#
#
#
#
# [16, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0067
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0198
# Preprocess Time per second: 0.0020
#
#
# Prediction Time: 0.0172
# Prediction Time per second: 0.0017
#
#
# Prediction Time: 1.3075
# Prediction Time per second: 0.1307
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3512
# Total Time per second: 0.1351
#
#
#
#
# [17, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0078
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0097
# Preprocess Time per second: 0.0010
#
#
# Prediction Time: 0.0153
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.3809
# Prediction Time per second: 0.1381
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.4137
# Total Time per second: 0.1414
#
#
#
#
# [18, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0046
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0118
# Preprocess Time per second: 0.0012
#
#
# Prediction Time: 0.0151
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.2904
# Prediction Time per second: 0.1290
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.3220
# Total Time per second: 0.1322
#
#
#
#
# [19, 2]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0054
# Spectrogram Time per second: 0.0005
#
#
# Preprocess Time: 0.0108
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.0154
# Prediction Time per second: 0.0015
#
#
# Prediction Time: 1.5580
# Prediction Time per second: 0.1558
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 1.5896
# Total Time per second: 0.1590
#
#
#
#
# [0, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0059
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.0080
# Preprocess Time per second: 0.0008
#
#
# Prediction Time: 0.0441
# Prediction Time per second: 0.0044
#
#
# Prediction Time: 0.0543
# Prediction Time per second: 0.0054
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.1123
# Total Time per second: 0.0112
#
#
#
#
# [1, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0097
# Spectrogram Time per second: 0.0010
#
#
# Preprocess Time: 0.0051
# Preprocess Time per second: 0.0005
#
#
# Prediction Time: 0.0373
# Prediction Time per second: 0.0037
#
#
# Prediction Time: 0.0347
# Prediction Time per second: 0.0035
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0867
# Total Time per second: 0.0087
#
#
#
#
# [2, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0075
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0105
# Preprocess Time per second: 0.0011
#
#
# Prediction Time: 0.0394
# Prediction Time per second: 0.0039
#
#
# Prediction Time: 0.0322
# Prediction Time per second: 0.0032
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0896
# Total Time per second: 0.0090
#
#
#
#
# [3, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0070
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0055
# Preprocess Time per second: 0.0006
#
#
# Prediction Time: 0.0309
# Prediction Time per second: 0.0031
#
#
# Prediction Time: 0.0331
# Prediction Time per second: 0.0033
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0765
# Total Time per second: 0.0077
#
#
#
#
# [4, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0063
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.0071
# Preprocess Time per second: 0.0007
#
#
# Prediction Time: 0.0302
# Prediction Time per second: 0.0030
#
#
# Prediction Time: 0.0335
# Prediction Time per second: 0.0033
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0770
# Total Time per second: 0.0077
#
#
#
#
# [5, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0080
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0056
# Preprocess Time per second: 0.0006
#
#
# Prediction Time: 0.0448
# Prediction Time per second: 0.0045
#
#
# Prediction Time: 0.0368
# Prediction Time per second: 0.0037
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0952
# Total Time per second: 0.0095
#
#
#
#
# [6, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0073
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0061
# Preprocess Time per second: 0.0006
#
#
# Prediction Time: 0.0308
# Prediction Time per second: 0.0031
#
#
# Prediction Time: 0.0318
# Prediction Time per second: 0.0032
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0759
# Total Time per second: 0.0076
#
#
#
#
# [7, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0065
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0055
# Preprocess Time per second: 0.0005
#
#
# Prediction Time: 0.0302
# Prediction Time per second: 0.0030
#
#
# Prediction Time: 0.0326
# Prediction Time per second: 0.0033
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0748
# Total Time per second: 0.0075
#
#
#
#
# [8, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0068
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0055
# Preprocess Time per second: 0.0005
#
#
# Prediction Time: 0.0304
# Prediction Time per second: 0.0030
#
#
# Prediction Time: 0.0336
# Prediction Time per second: 0.0034
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0764
# Total Time per second: 0.0076
#
#
#
#
# [9, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0068
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0053
# Preprocess Time per second: 0.0005
#
#
# Prediction Time: 0.0301
# Prediction Time per second: 0.0030
#
#
# Prediction Time: 0.0320
# Prediction Time per second: 0.0032
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0742
# Total Time per second: 0.0074
#
#
#
#
# [10, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0060
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.0074
# Preprocess Time per second: 0.0007
#
#
# Prediction Time: 0.0307
# Prediction Time per second: 0.0031
#
#
# Prediction Time: 0.0319
# Prediction Time per second: 0.0032
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0759
# Total Time per second: 0.0076
#
#
#
#
# [11, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0071
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0062
# Preprocess Time per second: 0.0006
#
#
# Prediction Time: 0.0361
# Prediction Time per second: 0.0036
#
#
# Prediction Time: 0.0328
# Prediction Time per second: 0.0033
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0822
# Total Time per second: 0.0082
#
#
#
#
# [12, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0068
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0050
# Preprocess Time per second: 0.0005
#
#
# Prediction Time: 0.0296
# Prediction Time per second: 0.0030
#
#
# Prediction Time: 0.0332
# Prediction Time per second: 0.0033
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0747
# Total Time per second: 0.0075
#
#
#
#
# [13, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0069
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0050
# Preprocess Time per second: 0.0005
#
#
# Prediction Time: 0.0310
# Prediction Time per second: 0.0031
#
#
# Prediction Time: 0.0340
# Prediction Time per second: 0.0034
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0770
# Total Time per second: 0.0077
#
#
#
#
# [14, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0066
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0058
# Preprocess Time per second: 0.0006
#
#
# Prediction Time: 0.0302
# Prediction Time per second: 0.0030
#
#
# Prediction Time: 0.0374
# Prediction Time per second: 0.0037
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0800
# Total Time per second: 0.0080
#
#
#
#
# [15, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0076
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0052
# Preprocess Time per second: 0.0005
#
#
# Prediction Time: 0.0316
# Prediction Time per second: 0.0032
#
#
# Prediction Time: 0.0366
# Prediction Time per second: 0.0037
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0810
# Total Time per second: 0.0081
#
#
#
#
# [16, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0061
# Spectrogram Time per second: 0.0006
#
#
# Preprocess Time: 0.0049
# Preprocess Time per second: 0.0005
#
#
# Prediction Time: 0.0296
# Prediction Time per second: 0.0030
#
#
# Prediction Time: 0.0332
# Prediction Time per second: 0.0033
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0738
# Total Time per second: 0.0074
#
#
#
#
# [17, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0065
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0053
# Preprocess Time per second: 0.0005
#
#
# Prediction Time: 0.0295
# Prediction Time per second: 0.0029
#
#
# Prediction Time: 0.0347
# Prediction Time per second: 0.0035
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0761
# Total Time per second: 0.0076
#
#
#
#
# [18, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0081
# Spectrogram Time per second: 0.0008
#
#
# Preprocess Time: 0.0052
# Preprocess Time per second: 0.0005
#
#
# Prediction Time: 0.0294
# Prediction Time per second: 0.0029
#
#
# Prediction Time: 0.0355
# Prediction Time per second: 0.0036
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0782
# Total Time per second: 0.0078
#
#
#
#
# [19, 3]
#
#
# (1723, 129)
# (1723, 128)
# Spectrogram Time: 0.0066
# Spectrogram Time per second: 0.0007
#
#
# Preprocess Time: 0.0067
# Preprocess Time per second: 0.0007
#
#
# Prediction Time: 0.0312
# Prediction Time per second: 0.0031
#
#
# Prediction Time: 0.0355
# Prediction Time per second: 0.0035
#
#
# Prediction Time: 0.0000
# Prediction Time per second: 0.0000
#
#
# Total Time: 0.0799
# Total Time per second: 0.0080

# %%
print('CNN: ' + str(np.mean(Times_OD[:,-1,0])) + ' +- ' + str(np.std(Times_OD[:,-1,0])) + '|' + str(np.std(Times_OD[:,-1,0])*0.43826932358995874))
print('RNN: ' + str(np.mean(Times_OD[:,-1,1])) + ' +- ' + str(np.std(Times_OD[:,-1,1])) + '|' + str(np.std(Times_OD[:,-1,1])*0.43826932358995874))
print('CRNN: ' + str(np.mean(Times_OD[:,-1,2])) + ' +- ' + str(np.std(Times_OD[:,-1,2])) + '|' + str(np.std(Times_OD[:,-1,2])*0.43826932358995874))
print('Online_RNN: ' + str(np.mean(Times_OD[:,-1,3])) + ' +- ' + str(np.std(Times_OD[:,-1,3])) + '|' + str(np.std(Times_OD[:,-1,3])*0.43826932358995874))
# MKL: 0.010587399303913116 +- 0.00016365101657776944|7.172322034034813e-05
# Out:
# CNN: 0.03077136754989624 +- 0.007016713097041222|0.0030752101028650607
# RNN: 0.023345335721969604 +- 0.0025444759181406777|0.001115165739534454
# CRNN: 0.1387440872192383 +- 0.006381819382093017|0.002796955663863195
# Online_RNN: 0.008086923360824585 +- 0.000901286064398591|0.0003950060338050265
